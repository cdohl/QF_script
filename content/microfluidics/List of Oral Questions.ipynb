# %% [markdown]
# ## Questions in oral exam
#
# 1. Define stream, streak-, and pathlines.
# 2. Give examples of stream, streak-, and pathlines.
# 3. Can Streamlines cross (in steady/unsteady) flows? Why/Why not?
# 4. When are stream, streak and pathlines identical?
# 5. Definition of stagnation point
# 6. Stagnation point flow
# 7. Explain material derivative and give an example for acceleration in stead flow
# 8. Write down the material derivative for one coordinate in a cartesian coordinate system
# 9. State incompressibility through density and velocity field.
# 10. Difference between Lagrangian and Eulerian description of a flow
# 11. What is the physical law used for the derivation of the Cauchy equation of motion?
# 12. What is missing in the Cauchy eqaution of motion, i.e. closure relation for example to derive the Navier Stokes (N.S.) equations?
# 13. Difference between body and surface forces, give examples.
# 14. Write down the incrompressible N.S. equations? Explain each term
# 15. How many unknowns are there in the N.S. equations? How many equations are there in the N.S. equations?
# 16. What is the Reynolds number?
# 17. Why is it advantageous to non-dimensionalize the N.S. equation?
# 18. How to solve for the remaining unknown?
# 19. Is the pressure in the incompressible N.S. equations a thermodynamic variable? Explain.
# 20. Sketch the flow in a finite gap driven by a pressure difference.
# 21. Sketch the flow in an infinite gap driven by a pressure difference.
# 22. Write down the Bernoulli Equation
# 23. What are the assumptions for the unsteady incompressible Bernoulli equation?
# 24. Show an example, where you can apply th steady/unsteady incompressible Bernoulli equation.
# 25. How to determine the Bernoulli constant? Is it necessary to know the constant? Is it truely a constant?
# 26. What are the two conditions for a potential flow?
# 27. Provide 2 solutions for potential flow in 2 dimensions
# 28. Why can I superimpose potential flow solutions?
# 29. What is the pressure drag for an object in a potential flow?
# 30. State the drag of sphere in a Stokes flow
# 31. What are the two necessary conditions for a Hele-Shaw flow?
# 32. What equation must a Hele-Shaw flow fulfill?
# 33. Difference between the Hele-Shaw flow and a potential flow
# 34. Application of Hele-Shaw flow
# 35. Explain hydraulic resistance by making an analogue to electric resistance
# 36. What is the origin of capillary effects?
# 37. How would you measure surface tension?
# 38. State the Laplace pressure of gas-bubble in a liquid, a soap bubble, and a cylindrical bubble in a liquid
# 39. Derive Young's equation (contact angle equation).
# 40. Explain the filling of a vertical/horizontal thin channel.
# 41. Derive the capillary length
# 42. Explain the Debye length
# 43. Sketch the concentrations of co/counter ions near a charged surface
# 44. Solve for the velocity resulting from the electrophoretic force
# 45. How does an electrosmotic pump work?
# 46. Viscosity of water at standard conditions
# 47. How are microfluidic channels manufactured?
# 48. Connect diffusion with random walk
# 49. How can one judge that a transport process is diffusion dominated?
# 50. What are transport coefficients? Name two of them
